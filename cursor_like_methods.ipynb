# %%
import pymongo

# %%
course_cluster_uri = "mongodb://agg-student:agg-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin"
course_client = pymongo.MongoClient(course_cluster_uri)

# %%
movies = course_client['aggregations']['movies']

# %%
list(movies.find({}).limit(5))
# Out:
# [{'_id': ObjectId('573a1390f29313caabcd4192'),
#   'title': 'The Conjuring of a Woman at the House of Robert Houdin',
#   'year': 1896,
#   'runtime': 1,
#   'cast': ["Jeanne d'Alcy", 'Georges M�li�s'],
#   'plot': 'A woman disappears on stage.',
#   'fullplot': 'An elegantly dressed man enters through a stage door onto a set with decorated back screen, a chair and small table. He brings a well-dressed women through the door, spreads a newspaper on the floor, and places the chair on it. She sits and fans herself; he covers her with a diaphanous cloth. She disappears; he tries to conjure her back with incomplete results. Can he go beyond the bare bones of a conjuring trick and succeed in the complete reconstitution of a the lady?',
#   'lastupdated': '2015-08-26 00:05:55.493000000',
#   'type': 'movie',
#   'directors': ['Georges M�li�s'],
#   'imdb': {'rating': 6.3, 'votes': 759, 'id': 75},
#   'countries': ['France'],
#   'genres': ['Short'],
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 59},
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 46, 29)}},
#  {'_id': ObjectId('573a1390f29313caabcd414a'),
#   'title': "Baby's Dinner",
#   'year': 1895,
#   'runtime': 1,
#   'released': datetime.datetime(1895, 12, 28, 0, 0),
#   'cast': ['Mrs. Auguste Lumiere', 'Andr�e Lumi�re', 'Auguste Lumi�re'],
#   'plot': 'A baby is seated at a table between its cheerful parents, Auguste and Marguerite Lumi�re. While the father is feeding the baby with a spoon, the mother is pouring coffee into her cup. The ...',
#   'fullplot': "A baby is seated at a table between its cheerful parents, Auguste and Marguerite Lumi�re. While the father is feeding the baby with a spoon, the mother is pouring coffee into her cup. The father gives the baby a biscuit, which the baby grabs, but doesn't eat, although both parents encourage it. The father resumes feeding the baby with the spoon.",
#   'lastupdated': '2015-08-12 00:06:40.657000000',
#   'type': 'movie',
#   'directors': ['Louis Lumi�re'],
#   'imdb': {'rating': 5.9, 'votes': 1669, 'id': 29},
#   'countries': ['France'],
#   'genres': ['Documentary', 'Short']},
#  {'_id': ObjectId('573a1390f29313caabcd41a9'),
#   'title': 'A Terrible Night',
#   'year': 1896,
#   'runtime': 1,
#   'cast': ['Georges M�li�s'],
#   'plot': "A man tries to get a good night's sleep, but is disturbed by a giant spider that leaps onto his bed, and a battle ensues in hilarious comic fashion.",
#   'fullplot': "A man tries to get a good night's sleep, but is disturbed by a giant spider that leaps onto his bed, and a battle ensues in hilarious comic fashion.",
#   'lastupdated': '2015-08-26 00:07:48.213000000',
#   'type': 'movie',
#   'directors': ['Georges M�li�s'],
#   'imdb': {'rating': 5.9, 'votes': 498, 'id': 131},
#   'countries': ['France'],
#   'genres': ['Short', 'Comedy']},
#  {'_id': ObjectId('573a1390f29313caabcd41aa'),
#   'title': 'Une partie de cartes',
#   'year': 1896,
#   'runtime': 1,
#   'cast': ['Gaston M�li�s', 'Georges M�li�s', 'Georgette M�li�s'],
#   'plot': 'Three friends are playing cards in a beer garden. One of them orders drinks. The waitress comes back with a bottle of wine and three glasses on a tray. The man serves his friends. They ...',
#   'fullplot': 'Three friends are playing cards in a beer garden. One of them orders drinks. The waitress comes back with a bottle of wine and three glasses on a tray. The man serves his friends. They clink glasses and drink. Then the man asks for a newspaper. He reads a funny story in it and the three friends burst out laughing while the waitress merely smiles.',
#   'lastupdated': '2015-07-27 00:27:37.370000000',
#   'type': 'movie',
#   'directors': ['Georges M�li�s'],
#   'writers': ['Georges M�li�s'],
#   'imdb': {'rating': 5.1, 'votes': 462, 'id': 132},
#   'countries': ['France'],
#   'genres': ['Short', 'Biography']},
#  {'_id': ObjectId('573a1390f29313caabcd4136'),
#   'title': 'Pauvre Pierrot',
#   'year': 1892,
#   'runtime': 4,
#   'released': datetime.datetime(1892, 10, 28, 0, 0),
#   'plot': 'One night, Arlequin come to see his lover Colombine. But then Pierrot knocks at the door and Colombine and Arlequin hide. Pierrot starts singing but Arlequin scares him and the poor man goes away.',
#   'fullplot': 'One night, Arlequin come to see his lover Colombine. But then Pierrot knocks at the door and Colombine and Arlequin hide. Pierrot starts singing but Arlequin scares him and the poor man goes away.',
#   'lastupdated': '2015-08-12 00:06:02.720000000',
#   'type': 'movie',
#   'directors': ['�mile Reynaud'],
#   'imdb': {'rating': 6.7, 'votes': 566, 'id': 3},
#   'countries': ['France'],
#   'genres': ['Animation', 'Comedy', 'Short'],
#   'num_mflix_comments': 1,
#   'comments': [{'name': 'Warren Wilson',
#     'email': 'warren_wilson@fakegmail.com',
#     'movie_id': ObjectId('573a1390f29313caabcd4136'),
#     'text': 'Repudiandae minus voluptates quidem hic corporis corrupti id. Ipsum assumenda laborum officiis aliquam. Dolorum voluptatum saepe blanditiis. Eos modi dolores architecto laboriosam porro.',
#     'date': datetime.datetime(2005, 1, 4, 11, 56, 37)}]}]

# %% [markdown]
# # Lab: Using Cursor-like aggregation stages
#
# ## For this lab, you'll have to use cursor-like aggregation stages to find the answer for the following scenario.
#
# #### The dataset for this lab can be downloaded [here](https://s3.amazonaws.com/edu-static.mongodb.com/lessons/coursera/aggregation/movies.json) for upload to your own cluster.
#
# ### Movie Night
#
# Your organization has a movie night scheduled, and you've again been tasked with coming up with a selection.
#
# HR has polled employees and assembled the following list of preferred actresses and actors.

# %%
favorites = [
  "Sandra Bullock",
  "Tom Hanks",
  "Julia Roberts",
  "Kevin Spacey",
  "George Clooney"
]

# %% [markdown]
# For movies released in the **USA** with a ``tomatoes.viewer.rating`` greater
# than or equal to **3**, calculate a new field called num_favs that represets how
# many **favorites** appear in the ``cast`` field of the movie.
#
# Sort your results by ``num_favs``, ``tomatoes.viewer.rating``, and ``title``,
# all in descending order.
#
# What is the ``title`` of the **25th** film in the aggregation result?
#
# **Hint**: MongoDB has a great expression for quickly determining whether there are common elements in lists, ``$setIntersection``

# %%
pipeline = [
    {
        "$match": {
            "$and": [
                {
                    "tomatoes.viewer.rating": { "$gte": 3 }
                },
                {
                   "countries": { "$in": [ "$countries", "USA"] } 
                },
                {
                    "cast": { "$elemMatch": { "$exists": "true" } }
                }
            ]
            
        }
    },
    {
        "$project": {
            "_id": 0,
            "title": 1,
            "cast": 1,
            "tomatoes.viewer.rating": 1,
            "num_favs": {
                "$size": { "$setIntersection": ["$cast", favorites] }
            }
        }
    },
    {
        "$sort": {
            "num_favs": -1, 
            "tomatoes.viewer.rating": -1,
            "title": -1
        }
    },
    {
        "$skip": 24
    }
]

display(list(movies.aggregate(pipeline, allowDiskUse=True)))
# Out:
# [{'title': 'The Heat',
#   'cast': ['Sandra Bullock',
#    'Melissa McCarthy',
#    'Demian Bichir',
#    'Marlon Wayans'],
#   'tomatoes': {'viewer': {'rating': 3.8}},
#   'num_favs': 1},
#  {'title': 'The Descendants',
#   'cast': ['George Clooney',
#    'Shailene Woodley',
#    'Amara Miller',
#    'Nick Krause'],
#   'tomatoes': {'viewer': {'rating': 3.8}},
#   'num_favs': 1},
#  {'title': 'Recount',
#   'cast': ['Kevin Spacey', 'Bob Balaban', 'Ed Begley Jr.', 'Laura Dern'],
#   'tomatoes': {'viewer': {'rating': 3.8}},
#   'num_favs': 1},
#  {'title': 'Look, Up in the Sky! The Amazing Story of Superman',
#   'cast': ['Kevin Spacey',
#    'Gerard Jones',
#    'Forrest J. Ackerman',
#    'Elliot S. Maggin'],
#   'tomatoes': {'viewer': {'rating': 3.8}},
#   'num_favs': 1},
#  {'title': 'L.A. Confidential',
#   'cast': ['Kevin Spacey', 'Russell Crowe', 'Guy Pearce', 'James Cromwell'],
#   'tomatoes': {'viewer': {'rating': 3.8}},
#   'num_favs': 1},
#  {'title': 'Inferno',
#   'cast': ['Tom Hanks', 'Felicity Jones', 'Ben Foster', 'Irrfan Khan'],
#   'tomatoes': {'viewer': {'rating': 3.8}},
#   'num_favs': 1},
#  {'title': 'American Beauty',
#   'cast': ['Kevin Spacey', 'Annette Bening', 'Thora Birch', 'Wes Bentley'],
#   'tomatoes': {'viewer': {'rating': 3.8}},
#   'num_favs': 1},
#  {'title': 'Up in the Air',
#   'cast': ['George Clooney', 'Vera Farmiga', 'Anna Kendrick', 'Jason Bateman'],
#   'tomatoes': {'viewer': {'rating': 3.7}},
#   'num_favs': 1},
#  {'title': 'Toy Story',
#   'cast': ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim Varney'],
#   'tomatoes': {'viewer': {'rating': 3.7}},
#   'num_favs': 1},
#  {'title': 'Philadelphia',
#   'cast': ['Tom Hanks', 'Denzel Washington', 'Roberta Maxwell', 'Buzz Kilman'],
#   'tomatoes': {'viewer': {'rating': 3.7}},
#   'num_favs': 1},
#  {'title': 'O Brother, Where Art Thou?',
#   'cast': ['Tim Blake Nelson',
#    'John Turturro',
#    'John Goodman',
#    'George Clooney'],
#   'tomatoes': {'viewer': {'rating': 3.7}},
#   'num_favs': 1},
#  {'title': 'Wrestling Ernest Hemingway',
#   'cast': ['Robert Duvall',
#    'Richard Harris',
#    'Shirley MacLaine',
#    'Sandra Bullock'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'The Life of David Gale',
#   'cast': ['Kate Winslet', 'Cleo King', 'Constance Jones', 'Kevin Spacey'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'The Ides of March',
#   'cast': ['Paul Giamatti',
#    'Philip Seymour Hoffman',
#    'Ryan Gosling',
#    'George Clooney'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'Swimming with Sharks',
#   'cast': ['Kevin Spacey',
#    'Frank Whaley',
#    'Michelle Forbes',
#    'Benicio Del Toro'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': "Ocean's Thirteen",
#   'cast': ['George Clooney', 'Brad Pitt', 'Matt Damon', 'Michael Mantell'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': "Ocean's Eleven",
#   'cast': ['George Clooney',
#    'Cecelia Ann Birt',
#    'Paul L. Nolan',
#    'Carol Florence'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'Michael Collins',
#   'cast': ['Ian Hart', 'Julia Roberts', 'Richard Ingram', 'Liam Neeson'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'I Love Trouble',
#   'cast': ['Nick Nolte', 'Julia Roberts', 'Saul Rubinek', 'James Rebhorn'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'Horrible Bosses',
#   'cast': ['Jason Bateman', 'Steve Wiebe', 'Kevin Spacey', 'Charlie Day'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'Comedy Central Roast of William Shatner',
#   'cast': ['William Shatner',
#    'Jason Alexander',
#    'Sandra Bullock',
#    "Debra 'Debbie' Clark"],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'Cloud Atlas',
#   'cast': ['Tom Hanks', 'Halle Berry', 'Jim Broadbent', 'Hugo Weaving'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'Catch Me If You Can',
#   'cast': ['Leonardo DiCaprio',
#    'Tom Hanks',
#    'Christopher Walken',
#    'Martin Sheen'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'August: Osage County',
#   'cast': ['Meryl Streep', 'Julia Roberts', 'Chris Cooper', 'Ewan McGregor'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'Apollo 13',
#   'cast': ['Tom Hanks', 'Bill Paxton', 'Kevin Bacon', 'Gary Sinise'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': '21',
#   'cast': ['Jim Sturgess', 'Kevin Spacey', 'Kate Bosworth', 'Aaron Yoo'],
#   'tomatoes': {'viewer': {'rating': 3.6}},
#   'num_favs': 1},
#  {'title': 'Toy Story 2',
#   'cast': ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Kelsey Grammer'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'The Thing Called Love',
#   'cast': ['River Phoenix',
#    'Samantha Mathis',
#    'Dermot Mulroney',
#    'Sandra Bullock'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'The Negotiator',
#   'cast': ['Samuel L. Jackson', 'Kevin Spacey', 'David Morse', 'Ron Rifkin'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'The Lake House',
#   'cast': ['Keanu Reeves',
#    'Sandra Bullock',
#    'Christopher Plummer',
#    'Ebon Moss-Bachrach'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'Pretty Woman',
#   'cast': ['Richard Gere',
#    'Julia Roberts',
#    'Ralph Bellamy',
#    'Jason Alexander'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'Pay It Forward',
#   'cast': ['Kevin Spacey', 'Helen Hunt', 'Haley Joel Osment', 'Jay Mohr'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'From Dusk Till Dawn',
#   'cast': ['George Clooney',
#    'Quentin Tarantino',
#    'Harvey Keitel',
#    'Juliette Lewis'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'Erin Brockovich',
#   'cast': ['Julia Roberts', 'David Brisbin', 'Dawn Didawick', 'Albert Finney'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'Big',
#   'cast': ['Tom Hanks', 'Elizabeth Perkins', 'Robert Loggia', 'John Heard'],
#   'tomatoes': {'viewer': {'rating': 3.5}},
#   'num_favs': 1},
#  {'title': 'The Terminal',
#   'cast': ['Stanley Tucci',
#    'Tom Hanks',
#    'Catherine Zeta-Jones',
#    'Chi McBride'],
#   'tomatoes': {'viewer': {'rating': 3.4}},
#   'num_favs': 1},
#  {'title': 'The Proposal',
#   'cast': ['Sandra Bullock',
#    'Ryan Reynolds',
#    'Mary Steenburgen',
#    'Craig T. Nelson'],
#   'tomatoes': {'viewer': {'rating': 3.4}},
#   'num_favs': 1},
#  {'title': 'The Big Kahuna',
#   'cast': ['Danny DeVito', 'Paul Dawson', 'Peter Facinelli', 'Kevin Spacey'],
#   'tomatoes': {'viewer': {'rating': 3.4}},
#   'num_favs': 1},
#  {'title': "Shackleton's Antarctic Adventure",
#   'cast': ['Kevin Spacey', 'Conrad Anker', 'Iain Fraser', 'Michael Gambon'],
#   'tomatoes': {'viewer': {'rating': 3.4}},
#   'num_favs': 1},
#  {'title': 'Minions',
#   'cast': ['Sandra Bullock', 'Jon Hamm', 'Michael Keaton', 'Allison Janney'],
#   'tomatoes': {'viewer': {'rating': 3.4}},
#   'num_favs': 1},
#  {'title': 'Angels & Demons',
#   'cast': ['Tom Hanks', 'Ewan McGregor', 'Ayelet Zurer', 'Stellan Skarsg�rd'],
#   'tomatoes': {'viewer': {'rating': 3.4}},
#   'num_favs': 1},
#  {'title': 'A League of Their Own',
#   'cast': ['Tom Hanks', 'Geena Davis', 'Lori Petty', 'Madonna'],
#   'tomatoes': {'viewer': {'rating': 3.4}},
#   'num_favs': 1},
#  {'title': 'Tomorrowland',
#   'cast': ['George Clooney',
#    'Hugh Laurie',
#    'Britt Robertson',
#    'Raffey Cassidy'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Three Kings',
#   'cast': ['George Clooney', 'Mark Wahlberg', 'Ice Cube', 'Spike Jonze'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'The Ref',
#   'cast': ['Denis Leary',
#    'Judy Davis',
#    'Kevin Spacey',
#    'Robert J. Steinmiller Jr.'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': "The 'Burbs",
#   'cast': ['Tom Hanks', 'Bruce Dern', 'Carrie Fisher', 'Rick Ducommun'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Superman Returns',
#   'cast': ['Brandon Routh', 'Kate Bosworth', 'Kevin Spacey', 'James Marsden'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Stepmom',
#   'cast': ['Julia Roberts', 'Susan Sarandon', 'Ed Harris', 'Jena Malone'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Speed',
#   'cast': ['Keanu Reeves', 'Dennis Hopper', 'Sandra Bullock', 'Joe Morton'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Sleepless in Seattle',
#   'cast': ['Tom Hanks', 'Ross Malinger', 'Rita Wilson', 'Victor Garber'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'See No Evil, Hear No Evil',
#   'cast': ['Richard Pryor', 'Gene Wilder', 'Joan Severance', 'Kevin Spacey'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Ordinary Decent Criminal',
#   'cast': ['Kevin Spacey',
#    'Linda Fiorentino',
#    'Peter Mullan',
#    'Stephen Dillane'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': "Ocean's Twelve",
#   'cast': ['Brad Pitt', 'Catherine Zeta-Jones', 'George Clooney', 'Ed Kross'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Notting Hill',
#   'cast': ['Julia Roberts', 'Hugh Grant', 'Richard McCabe', 'Rhys Ifans'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Mystic Pizza',
#   'cast': ['Annabeth Gish',
#    'Julia Roberts',
#    'Lili Taylor',
#    "Vincent D'Onofrio"],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': "My Best Friend's Wedding",
#   'cast': ['Julia Roberts',
#    'Dermot Mulroney',
#    'Cameron Diaz',
#    'Rupert Everett'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Midnight in the Garden of Good and Evil',
#   'cast': ['John Cusack', 'Kevin Spacey', 'Jack Thompson', 'Irma P. Hall'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Infamous',
#   'cast': ['Sigourney Weaver',
#    'Toby Jones',
#    'Gwyneth Paltrow',
#    'Sandra Bullock'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Hope Floats',
#   'cast': ['Sandra Bullock',
#    'Harry Connick Jr.',
#    'Gena Rowlands',
#    'Mae Whitman'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Hook',
#   'cast': ['Dustin Hoffman', 'Robin Williams', 'Julia Roberts', 'Bob Hoskins'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': "Charlotte's Web",
#   'cast': ['Julia Roberts', 'Steve Buscemi', 'John Cleese', 'Oprah Winfrey'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Burn After Reading',
#   'cast': ['George Clooney',
#    'Frances McDormand',
#    'Brad Pitt',
#    'John Malkovich'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'Beyond the Sea',
#   'cast': ['Kevin Spacey', 'Kate Bosworth', 'John Goodman', 'Bob Hoskins'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': "A Bug's Life",
#   'cast': ['Dave Foley',
#    'Kevin Spacey',
#    'Julia Louis-Dreyfus',
#    'Hayden Panettiere'],
#   'tomatoes': {'viewer': {'rating': 3.3}},
#   'num_favs': 1},
#  {'title': 'While You Were Sleeping',
#   'cast': ['Sandra Bullock', 'Bill Pullman', 'Peter Gallagher', 'Peter Boyle'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'The Shipping News',
#   'cast': ['Kevin Spacey', 'Julianne Moore', 'Judi Dench', 'Cate Blanchett'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'The Prince of Egypt',
#   'cast': ['Val Kilmer',
#    'Ralph Fiennes',
#    'Michelle Pfeiffer',
#    'Sandra Bullock'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'The Polar Express',
#   'cast': ['Tom Hanks', 'Leslie Zemeckis', 'Eddie Deezen', 'Nona Gaye'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'The Pelican Brief',
#   'cast': ['Julia Roberts', 'Denzel Washington', 'Sam Shepard', 'John Heard'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Sleeping with the Enemy',
#   'cast': ['Julia Roberts',
#    'Patrick Bergin',
#    'Kevin Anderson',
#    'Elizabeth Lawrence'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Practical Magic',
#   'cast': ['Sandra Bullock',
#    'Nicole Kidman',
#    'Stockard Channing',
#    'Dianne Wiest'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Out of Sight',
#   'cast': ['George Clooney', 'Jennifer Lopez', 'Jim Robinson', 'Mike Malone'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Miss Congeniality',
#   'cast': ['Sandra Bullock',
#    'Michael Caine',
#    'Benjamin Bratt',
#    'Candice Bergen'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'K-PAX',
#   'cast': ['Kevin Spacey', 'Jeff Bridges', 'Mary McCormack', 'Alfre Woodard'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Hurlyburly',
#   'cast': ['Sean Penn', 'Kevin Spacey', 'Robin Wright', 'Chazz Palminteri'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Flatliners',
#   'cast': ['Kiefer Sutherland',
#    'Julia Roberts',
#    'Kevin Bacon',
#    'William Baldwin'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Dying Young',
#   'cast': ['Julia Roberts',
#    'Campbell Scott',
#    "Vincent D'Onofrio",
#    'Colleen Dewhurst'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Divine Secrets of the Ya-Ya Sisterhood',
#   'cast': ['Sandra Bullock',
#    'Ellen Burstyn',
#    'Fionnula Flanagan',
#    'James Garner'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': 'Conspiracy Theory',
#   'cast': ['Mel Gibson', 'Julia Roberts', 'Patrick Stewart', 'Cylk Cozart'],
#   'tomatoes': {'viewer': {'rating': 3.2}},
#   'num_favs': 1},
#  {'title': "You've Got Mail",
#   'cast': ['Tom Hanks', 'Meg Ryan', 'Greg Kinnear', 'Parker Posey'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'The Vanishing',
#   'cast': ['Jeff Bridges',
#    'Kiefer Sutherland',
#    'Nancy Travis',
#    'Sandra Bullock'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'The Monuments Men',
#   'cast': ['George Clooney', 'Matt Damon', 'Bill Murray', 'Cate Blanchett'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'The Ant Bully',
#   'cast': ['Julia Roberts', 'Nicolas Cage', 'Meryl Streep', 'Paul Giamatti'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'Shrink',
#   'cast': ['Kevin Spacey', 'Joe Nunez', 'Mark Webber', 'Keke Palmer'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'Premonition',
#   'cast': ['Sandra Bullock',
#    'Julian McMahon',
#    'Shyann McClure',
#    'Courtney Taylor Burness'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'Outbreak',
#   'cast': ['Dustin Hoffman', 'Rene Russo', 'Morgan Freeman', 'Kevin Spacey'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'One Fine Day',
#   'cast': ['Michelle Pfeiffer',
#    'George Clooney',
#    'Mae Whitman',
#    'Alex D. Linz'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'Mona Lisa Smile',
#   'cast': ['Julia Roberts',
#    'Kirsten Dunst',
#    'Julia Stiles',
#    'Maggie Gyllenhaal'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'Mirror Mirror',
#   'cast': ['Julia Roberts', 'Lily Collins', 'Armie Hammer', 'Nathan Lane'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'Iron Will',
#   'cast': ['Mackenzie Astin',
#    'Kevin Spacey',
#    'David Ogden Stiers',
#    'August Schellenberg'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'Demolition Man',
#   'cast': ['Sylvester Stallone',
#    'Wesley Snipes',
#    'Sandra Bullock',
#    'Nigel Hawthorne'],
#   'tomatoes': {'viewer': {'rating': 3.1}},
#   'num_favs': 1},
#  {'title': 'Two Weeks Notice',
#   'cast': ['Sandra Bullock', 'Dana Ivey', 'Hugh Grant', 'Alicia Witt'],
#   'tomatoes': {'viewer': {'rating': 3.0}},
#   'num_favs': 1},
#  {'title': 'Turner & Hooch',
#   'cast': ['Tom Hanks',
#    'Mare Winningham',
#    'Craig T. Nelson',
#    'Reginald VelJohnson'],
#   'tomatoes': {'viewer': {'rating': 3.0}},
#   'num_favs': 1},
#  {'title': 'Something to Talk About',
#   'cast': ['Julia Roberts', 'Dennis Quaid', 'Robert Duvall', 'Gena Rowlands'],
#   'tomatoes': {'viewer': {'rating': 3.0}},
#   'num_favs': 1},
#  {'title': 'Secret in Their Eyes',
#   'cast': ['Julia Roberts',
#    'Nicole Kidman',
#    'Lyndon Smith',
#    'Chiwetel Ejiofor'],
#   'tomatoes': {'viewer': {'rating': 3.0}},
#   'num_favs': 1},
#  {'title': 'Runaway Bride',
#   'cast': ['Julia Roberts', 'Richard Gere', 'Joan Cusack', 'Hector Elizondo'],
#   'tomatoes': {'viewer': {'rating': 3.0}},
#   'num_favs': 1},
#  {'title': 'In Love and War',
#   'cast': ['Mackenzie Astin',
#    "Chris O'Donnell",
#    'Margot Steinberg',
#    'Sandra Bullock'],
#   'tomatoes': {'viewer': {'rating': 3.0}},
#   'num_favs': 1},
#  {'title': 'Eat Pray Love',
#   'cast': ['Julia Roberts',
#    'I. Gusti Ayu Puspawati',
#    'Hadi Subiyanto',
#    'Billy Crudup'],
#   'tomatoes': {'viewer': {'rating': 3.0}},
#   'num_favs': 1},
#  {'title': 'Wonder Women! The Untold Story of American Superheroines',
#   'cast': ['Lynda Carter', 'Jane Espenson', 'Kathleen Hanna', 'L.S. Kim'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Virgin High',
#   'cast': ['Richard Gabai', 'Tracy Dali', 'Burt Ward', 'Maureen LaVette'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Uncanny',
#   'cast': ['Mark Webber',
#    'Lucy Griffiths',
#    'David Clayton Rogers',
#    'Rainn Wilson'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Unbranded',
#   'cast': ['Jonny Fitzsimons', 'Thomas Glover', 'Ben Masters', 'Ben Thamer'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Tumbledown',
#   'cast': ['Brad Hallowell', 'Brett Faulkner', 'Todd Verow', 'Erica LaChance'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'This Is the Life',
#   'cast': ['2Mex', 'Busdriver', 'Brian Cross', 'Nga Fsh'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Wild Bunch: An Album in Montage',
#   'cast': ['Nick Redman', 'Walon Green', 'Newell Alexander', "Edmond O'Brien"],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Touch of Her Flesh',
#   'cast': ['Suzanne Marre', 'Angelique', 'Michael Findlay', 'Vivian Del Rio'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Third Jihad',
#   'cast': ['Omar Ahmad',
#    'Mahmoud Ahmadinejad',
#    'Younus Al-Astal',
#    'Ahmad Husseini Al-Baghdadi'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Other Me',
#   'cast': ['Andrew Lawrence', 'Mark L. Taylor', 'Lori Hallier', 'Alison Pill'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Naughty Flirt',
#   'cast': ['Alice White', 'Paul Page', 'Myrna Loy', 'Robert Agnew'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Magnificent Seven',
#   'cast': ['Chris Pratt',
#    'Matt Bomer',
#    "Vincent D'Onofrio",
#    'Denzel Washington'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Last Lovecraft: Relic of Cthulhu',
#   'cast': ['Kyle Davis', 'Devin McGinn', 'Matt Bauer', 'Honor Bliss'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Hunters',
#   'cast': ['Robbie Amell', 'Alexa PenaVega', 'Victor Garber', 'Kira Clavell'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Houston Story',
#   'cast': ['Gene Barry', 'Barbara Hale', 'Edward Arnold', 'Paul Richards'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Girl from Nagasaki',
#   'cast': ['Mariko Wordell',
#    'Edoardo Ponti',
#    'Paulina Semionova',
#    'Ayako Yoshida'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Flying Fleet',
#   'cast': ['Ramon Novarro', 'Ralph Graves', 'Anita Page'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Crowded Sky',
#   'cast': ['Dana Andrews',
#    'Rhonda Fleming',
#    'Efrem Zimbalist Jr.',
#    'John Kerr'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Color of Rain',
#   'cast': ['Lacey Chabert',
#    'Warren Christie',
#    'Matthew Kevin Anderson',
#    'Logan Williams'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Coalition',
#   'cast': ['Denyce Lawton', 'Eddie Goines', 'Adrienne Bailon', 'J.R. Ramirez'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Best of Ernie and Bert',
#   'cast': ['Alison Bartlett', 'Jim Henson', 'Jerry Nelson', 'Frank Oz'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Tar Creek',
#   'cast': ['John Frazier', 'Earl Hatley', 'Matt Myers', 'Bob Nairn'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Summer Camp',
#   'cast': ['Diego Boneta',
#    'Maiara Walsh',
#    'Jocelin Donahue',
#    'Andr�s Velencoso'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Steve Jobs: The Lost Interview',
#   'cast': ['Steve Jobs', 'Robert X. Cringely'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Starring Adam West',
#   'cast': ['Tom Kenny', 'Seth MacFarlane', 'Scott Sebring', 'Burt Ward'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Star Trek Beyond',
#   'cast': ['Simon Pegg', 'Chris Pine', 'Zoe Saldana', 'Idris Elba'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Silenced',
#   'cast': ['Marc Basil',
#    'Jeffrey Brewer',
#    'Garlan Green',
#    'Michael Wren Gucciardo'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Shelter Island',
#   'cast': ['Brittany Olinkiewicz', 'James Olinkiewicz', 'Harald Olsen'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'She Had to Say Yes',
#   'cast': ['Loretta Young', 'Winnie Lightner', 'Lyle Talbot', 'Regis Toomey'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Scooby-Doo! Stage Fright',
#   'cast': ['Isabella Acres', 'Troy Baker', 'Eric Bauza', 'Jeff Bennett'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Scooby-Doo! Mask of the Blue Falcon',
#   'cast': ['Frank Welker', 'Mindy Cohn', 'Grey Griffin', 'Matthew Lillard'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Scooby-Doo! Camp Scare',
#   'cast': ['Frank Welker', 'Mindy Cohn', 'Matthew Lillard', 'Grey Griffin'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Rosenwald',
#   'cast': ['Peter Ascoli',
#    'Julian Bond',
#    'Stephanie Deutsch',
#    'Richard J. Powell'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "Rosemary's Baby",
#   'cast': ['Zoe Saldana',
#    'Patrick J. Adams',
#    'Carole Bouquet',
#    'Christina Cole'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Rise of the Zombies',
#   'cast': ['Ethan Suplee', 'Mariel Hemingway', 'LeVar Burton', 'Danny Trejo'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Return to House on Haunted Hill',
#   'cast': ['Amanda Righetti', 'Cerina Vincent', 'Erik Palladino', 'Tom Riley'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Project Bigfoot',
#   'cast': ['Andy Goldenberg',
#    "Emily O'Brien",
#    'Nick Armstrong',
#    'Arnie Pantoja'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Pope John Paul II',
#   'cast': ['Jon Voight', 'Cary Elwes', 'James Cromwell', 'Christopher Lee'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "Pinocchio's Christmas",
#   'cast': ['Alan King', 'George S. Irving', 'Bob McFadden', 'Patricia Bright'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Phantom Halo',
#   'cast': ['Thomas Brodie-Sangster',
#    'Rebecca Romijn',
#    'Clare Grant',
#    'Luke Kleintank'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Panama Hattie',
#   'cast': ['Red Skelton', 'Ann Sothern', 'Rags Ragland', 'Ben Blue'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Out of Time',
#   'cast': ['Denzel Washington', 'Eva Mendes', 'Sanaa Lathan', 'Dean Cain'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Our Mr. Sun',
#   'cast': ['Eddie Albert',
#    'Lionel Barrymore',
#    'Frank Baxter',
#    'Marvin Miller'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "Orion's Key",
#   'cast': ['Todd Jensen',
#    'Frank Zagarino',
#    'Jennifer MacDonald',
#    'Greg Melvill-Smith'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'My Last Year with the Nuns',
#   'cast': ['Matt Smith'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Murder by Natural Causes',
#   'cast': ['Hal Holbrook',
#    'Katharine Ross',
#    'Richard Anderson',
#    'Barry Bostwick'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Mortal Kombat: Conquest',
#   'cast': ['Paolo Montalban',
#    'Daniel Bernhardt',
#    'Kristanna Loken',
#    'Tracy Douglas'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "Mike Birbiglia: My Girlfriend's Boyfriend",
#   'cast': ['Mike Birbiglia'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Meet the Patels',
#   'cast': ['Champa V. Patel', 'Geeta Patel', 'Ravi Patel', 'Vasant K. Patel'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Marriage Retreat',
#   'cast': ['Jeff Fahey',
#    'David A.R. White',
#    'Anna Zielinski',
#    'Victoria Jackson'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Luis Martinetti, Contortionist',
#   'cast': ['Luis Martinetti'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Lovestruck: The Musical',
#   'cast': ['Jane Seymour', 'Sara Paxton', 'Chelsea Kane', 'Drew Seeley'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Living with the Fosters',
#   'cast': ['Joe Anderson', 'Rachel Finan', 'Jeff Heilman', 'Liz Hinkley'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Living on One Dollar',
#   'cast': ['Ryan Christoffersen',
#    'Zach Ingrasci',
#    'Sean Leonard',
#    'Chris Temple'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Licks',
#   'cast': ['Stanley Doe Hunt',
#    'Koran Streets',
#    'Les Aderibigbe',
#    'Devon Libran'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Jacques Brel Is Alive and Well and Living in Paris',
#   'cast': ['Elly Stone', 'Mort Shuman', 'Joe Masiell', 'Jacques Brel'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "It's Just a Ride",
#   'cast': ['Bill Hicks', 'Jay Leno', 'David Letterman'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Island of Blood',
#   'cast': ['Marie-Alise Recasner',
#    'Rick Dean',
#    'Ron Gardner',
#    'Terence Goodman'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Inside the X Files',
#   'cast': ['Chris Carter',
#    'David Duchovny',
#    'Gillian Anderson',
#    'William B. Davis'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Incredible Rocky Mountain Race',
#   'cast': ['Christopher Connelly',
#    'Forrest Tucker',
#    'Larry Storch',
#    'Jack Kruschen'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Identical',
#   'cast': ['Jonathan Togo',
#    'Emily Baldoni',
#    'Aaron Refvem',
#    'Meredith Zinner'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'I Am So Proud of You',
#   'cast': ['Don Hertzfeldt'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Hello, My Name Is Frank',
#   'cast': ['Garrett M. Brown',
#    'Rachel DiPillo',
#    'Mary Kate Wiles',
#    'Hayley Kiyoko'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Having Wonderful Time',
#   'cast': ['Ginger Rogers',
#    'Douglas Fairbanks Jr.',
#    'Peggy Conklin',
#    'Lucille Ball'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "Good Ol' Boy",
#   'cast': ['Jason Lee', 'Anjul Nigam', 'Brighton Sharbino', 'Hilarie Burton'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Ghost Adventures',
#   'cast': ['Zak Bagans', 'Aaron Goodwin', 'Nick Groff', 'Mike Hardy'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Frenemies',
#   'cast': ['Bella Thorne', 'Zendaya', 'Mary Mouser', 'Nick Robinson'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Fearful Symmetry',
#   'cast': ['Mary Williams', 'Horton Foote', 'Robert Mulligan', 'A.B. Blass'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Falling Skies',
#   'cast': ['Noah Wyle', 'Maxim Knight', 'Drew Roy', 'Will Patton'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Everybody Wants Some',
#   'cast': ['Tyler Hoechlin', 'Zoey Deutch', 'Ryan Guzman', 'Wyatt Russell'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Every Second Counts',
#   'cast': ['Josh Everett', 'James FitzGerald', 'Dutch Lowy', 'Matt Murski'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Ed Wood: Look Back in Angora',
#   'cast': ['Conrad Brooks',
#    'Dolores Fuller',
#    'Kathy Wood',
#    'Edward D. Wood Jr.'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Dragon Hunter',
#   'cast': ['Kelly Stables', 'Brad Johnson', 'Newell Alexander', 'Erik Denton'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Curtain',
#   'cast': ['Danni Smith', 'Tim Lueke', 'Martin Monahan', 'Rick Zahn'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Crocodile Gennadiy',
#   'cast': ['Gennadiy Mokhnenko'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Colt Comrades',
#   'cast': ['William Boyd', 'Andy Clyde', 'Jay Kirby', 'Teddi Sherman'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Chris Hardwick: Mandroid',
#   'cast': ['Chris Hardwick'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Carrie Pilby',
#   'cast': ['Bel Powley', 'Jason Ritter', 'Tom Wilkinson', 'Vanessa Bayer'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Butterfly Girl',
#   'cast': ['Abigail Evans', 'John Evans', 'Stacie Evans', 'Mark A. Gilger'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Bubblegum & Broken Fingers',
#   'cast': ['Camme Tyla', 'Mandy Williams', 'Brenna Daly', 'Jason Nious'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Boycrazy',
#   'cast': ['James May', 'Navaris Darson', 'Brandon Alter', 'R.J. Enriquez'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Bottom of the World',
#   'cast': ['Jena Malone', 'Ted Levine', 'Douglas Smith', 'Tamara Duarte'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Bird of Prey',
#   'cast': ['Jennifer Tilly',
#    'Boyan Milushev',
#    'Richard Chamberlain',
#    'Lenny von Dohlen'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "Beethoven's Christmas Adventure",
#   'cast': ['John Cleese', 'Munro Chambers', 'Kim Rhodes', 'Jan Skene'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Banana',
#   'cast': ['Pierre Coffin'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'All American Chump',
#   'cast': ['Stuart Erwin',
#    'Robert Armstrong',
#    'Betty Furness',
#    'Edmund Gwenn'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "Alice's Wonderland",
#   'cast': ['Virginia Davis', 'Walt Disney', 'Hugh Harman', 'Rudolf Ising'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'Affluenza',
#   'cast': ['Ben Rosenfield', 'Gregg Sulkin', 'Nicola Peltz', 'Grant Gustin'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'A Taste of Romance',
#   'cast': ['Teri Polo',
#    'James Patrick Stuart',
#    'Alexander Bedria',
#    'Jack Conley'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'A Real American Hero',
#   'cast': ['Brian Dennehy', 'Forrest Tucker', 'Brian Kerwin', 'Ken Howard'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': "A Midsummer Night's Dream",
#   'cast': ['Stanley Tucci',
#    'Michelle Pfeiffer',
#    'Kevin Kline',
#    'Rupert Everett'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'A Lamp in the Dark: The Untold History of the Bible',
#   'cast': ['David Brown', 'Kirk Divietro', 'Jack Moorman', "Alan O'Reilly"],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'A Bit of Bad Luck',
#   'cast': ['Michael Agostini',
#    'Marshall Bell',
#    'Scott C. Brown',
#    'Agnes Bruckner'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'A Big Love Story',
#   'cast': ['Robbie Kaller',
#    'Jillian Leigh',
#    'Tommy Snider',
#    'Constance Reese'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': '6 Bullets',
#   'cast': ['Jean-Claude Van Damme',
#    'Joe Flanigan',
#    'Anna-Louise Plowman',
#    'Charlotte Beaumont'],
#   'tomatoes': {'viewer': {'rating': 5.0}},
#   'num_favs': 0},
#  {'title': 'The Image Revolution',
#   'cast': ['Charlie Adlard',
#    'Greg Aronowitz',
#    'Ryan Benjamin',
#    'Tim Callahan'],
#   'tomatoes': {'viewer': {'rating': 4.9}},
#   'num_favs': 0},
#  {'title': 'Marvin Hamlisch: What He Did for Love',
#   'cast': ['Woody Allen', 'Ann-Margret', 'Lucie Arnaz', 'Carole Bayer Sager'],
#   'tomatoes': {'viewer': {'rating': 4.9}},
#   'num_favs': 0},
#  {'title': 'Locusts: The 8th Plague',
#   'cast': ['Dan Cortese', 'David Keith', 'Kirk B.R. Woller', 'Jeff Fahey'],
#   'tomatoes': {'viewer': {'rating': 4.9}},
#   'num_favs': 0},
#  {'title': 'Building a Broken Mousetrap',
#   'cast': ['The Ex'],
#   'tomatoes': {'viewer': {'rating': 4.9}},
#   'num_favs': 0},
#  {'title': 'Bad Boys 3',
#   'cast': ['Will Smith', 'Martin Lawrence'],
#   'tomatoes': {'viewer': {'rating': 4.9}},
#   'num_favs': 0},
#  {'title': 'Zootopia',
#   'cast': ['Jason Bateman', 'Ginnifer Goodwin', 'Alan Tudyk', 'Katie Lowes'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Trapped in the Closet: Chapters 23-33',
#   'cast': ['R. Kelly', 'Eric Lane', 'Molly Pan', 'Tracey Bonner'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'The Taiwan Oyster',
#   'cast': ['Billy Harvey', 'Jeff Palmiotti', 'Leonora Lim-Moore', 'Erin King'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'The Life & Adventures of Santa Claus',
#   'cast': ['Robby Benson', 'Dixie Carter', 'Hal Holbrook', 'Carlos Alazraqui'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'The Journey',
#   'cast': ['Eric Saperston', 'Jimmy Carter', 'Max Cleland', 'Billy Crystal'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'The Forest',
#   'cast': ['Aidan Bristow', 'Kai Elle', 'Michael Madsen', 'Johnny Young'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Sand Castles',
#   'cast': ['Jordon Hodges', 'Anne Winters', 'Randy Spence', 'Saxon Trainor'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': "Pete's Dragon",
#   'cast': ['Bryce Dallas Howard',
#    'Karl Urban',
#    'Robert Redford',
#    'Wes Bentley'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Pernicious',
#   'cast': ['Ciara Hanna',
#    "Emily O'Brien",
#    'Jackie Moore',
#    'Russell Geoffrey Banks'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Icebreaker',
#   'cast': ['Sean Astin', 'Bruce Campbell', 'Stacy Keach', 'Suzanne Turner'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Hard Sun',
#   'cast': ['Robyn Buck', 'John Bain', 'Ben Begley', 'Tamara Carey'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Digital Dharma',
#   'cast': ['E. Gene Smith',
#    'Matthieu Ricard',
#    'Khyentse Norbu',
#    'Gray Tuttle'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'David Copperfield',
#   'cast': ['Michael Richards',
#    'Eileen Atkins',
#    'Anthony Andrews',
#    'Frank McCusker'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Cry Baby Lane',
#   'cast': ['Jase Blankfort', 'Trey Rogers', 'Frank Langella', 'Larc Spies'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Champs',
#   'cast': ['Evander Holyfield',
#    'Bernard Hopkins',
#    'Mike Tyson',
#    "Larry 'Ratso' Sloman"],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'Black Indians: An American Story',
#   'cast': ['James Earl Jones'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'American Idiots',
#   'cast': ['Jeffrey T. Schoettlin',
#    'Sean Muramatsu',
#    "Caroline D'Amore",
#    'Nick Faltas'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': 'After Last Season',
#   'cast': ['Jason Kulas',
#    'Peggy McClellan',
#    'Scott Winters',
#    'Casey McDougal'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': '616: Paranormal Incident',
#   'cast': ['Thomas Downey', 'Jennefer Ludwigsen', 'Rib Hillis', 'Eve Mauro'],
#   'tomatoes': {'viewer': {'rating': 4.8}},
#   'num_favs': 0},
#  {'title': "Wyatt Earp's Revenge",
#   'cast': ['Val Kilmer', 'Shawn Roberts', 'Daniel Booko', 'Matt Dallas'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Who Took Johnny',
#   'cast': ['Noreen Gosch'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Twinsters',
#   'cast': ['Anais Bordier', 'Samantha Futerman'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'The Invisible Front',
#   'cast': ['Andrius Mamontovas', 'Darius Udrys'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Star Wars: Episode VII - The Force Awakens',
#   'cast': ['Simon Pegg', 'Oscar Isaac', 'Mark Hamill', 'Harrison Ford'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Spectre',
#   'cast': ['Monica Bellucci', 'Daniel Craig', 'L�a Seydoux', 'Ralph Fiennes'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Soundtracker',
#   'cast': ['Gordon Hempton'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Paramore: The Final Riot!',
#   'cast': ['Jeremy Davis', 'Josh Farro', 'Zac Farro', 'Hayley Williams'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Muffin Top: A Love Story',
#   'cast': ['Cathryn Michon',
#    'Marissa Jaret Winokur',
#    'Diedrich Bader',
#    'Jill Holden'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Mega Python vs. Gatoroid',
#   'cast': ['Tiffany', 'Debbie Gibson', 'A Martinez', 'Kathryn Joosten'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Kafka',
#   'cast': ['Jeremy Irons', 'Theresa Russell', 'Joel Grey', 'Ian Holm'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Jack, Jules, Esther & Me',
#   'cast': ['Antonio Aguinaga',
#    'Nadia Bowers',
#    'Harrison Chad',
#    'Gilbert Cruz'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Helicopter Mom',
#   'cast': ['Nia Vardalos',
#    'Jason Dolley',
#    'Mark Boone Junior',
#    'Skyler Samuels'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Finding Dory',
#   'cast': ['Ellen DeGeneres', 'Albert Brooks', 'Diane Keaton', 'Eugene Levy'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Doctor Strange',
#   'cast': ['Rachel McAdams',
#    'Benedict Cumberbatch',
#    'Mads Mikkelsen',
#    'Tilda Swinton'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'Deadpool',
#   'cast': ['Morena Baccarin', 'Ryan Reynolds', 'Ed Skrein', 'Gina Carano'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'An Act of War',
#   'cast': ['Russ Russo',
#    'Natasha Alam',
#    'Doug E. Doug',
#    'Joseph R. Gannascoli'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': '100 Years of Evil',
#   'cast': ['Jon Rekdal',
#    'Jordi Almeida',
#    'Alexander Bareis',
#    'Tobias Bengtsson'],
#   'tomatoes': {'viewer': {'rating': 4.7}},
#   'num_favs': 0},
#  {'title': 'The Cross',
#   'cast': ['Arthur Blessitt'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Teenage Paparazzo',
#   'cast': ['Alec Baldwin', 'Jennifer Birn', 'Lewis Black', 'Noam Chomsky'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Symphony of the Soil',
#   'cast': ['Ignacio Chapela', 'Dan Barber', 'Vandana Shiva', 'Daniel Hillel'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Speciesism: The Movie',
#   'cast': ['Steven Best',
#    'Richard Dawkins',
#    'Gary Francione',
#    'Temple Grandin'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Runoff',
#   'cast': ['Joanne Kelly',
#    'Neal Huff',
#    'Alex Shaffer',
#    'Kivlighan de Montebello'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Poolboy: Drowning Out the Fury',
#   'cast': ['Kevin Sorbo', 'Ross Patterson', 'Danny Trejo', 'Jason Mewes'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'cast': ['Johnny Depp',
#    'Kaya Scodelario',
#    'Orlando Bloom',
#    'Brenton Thwaites'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Phantom of the Woods',
#   'cast': ['Delaney Hathaway',
#    'J.R.S. Storch',
#    'Richard Hackel',
#    'Mark S. Esch'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Original Cast Album: Company',
#   'cast': ['Barbara Barrie',
#    'Charles Braswell',
#    'Susan Browning',
#    'George Coe'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Musicwood',
#   'cast': ['The Antlers', 'Dave Berryman', 'Turin Brakes', 'Kaki King'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Money Matters',
#   'cast': ['Terri Abney',
#    'Aunjanue Ellis',
#    'James Whalen',
#    'Victoria Wallace'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': "Miss Peregrine's Home for Peculiar Children",
#   'cast': ['Kim Dickens', 'Eva Green', 'Samuel L. Jackson', 'Asa Butterfield'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Minecraft: The Story of Mojang',
#   'cast': ['Jens Bergensten',
#    'Jonathan Blow',
#    'Lewis Brindley',
#    'Brent Copeland'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Lewis Black: Black on Broadway',
#   'cast': ['Lewis Black'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': "Kickin' It Old Skool",
#   'cast': ['Jamie Kennedy',
#    'Maria Menounos',
#    'Miguel A. N��ez Jr.',
#    'Michael Rosenbaum'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'I Love Lucy',
#   'cast': ['Lucille Ball', 'Desi Arnaz', 'Vivian Vance', 'William Frawley'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Hybrid',
#   'cast': ['Milford Beeghly'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'He Never Died',
#   'cast': ['Booboo Stewart', 'Steven Ogg', 'Henry Rollins', 'Jordan Todosey'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Frozen Planet',
#   'cast': ['David Attenborough', 'Alec Baldwin'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'City of Gold',
#   'cast': ['Jonathan Gold', 'Allen Salkin'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Batman v Superman: Dawn of Justice',
#   'cast': ['Henry Cavill', 'Amy Adams', 'Jason Momoa', 'Ben Affleck'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'At the River I Stand',
#   'cast': ['Paul Winfield'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': "Assassin's Creed",
#   'cast': ['Michael Fassbender',
#    'Marion Cotillard',
#    'Michael Kenneth Williams',
#    'Ariane Labed'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'A Girl Like Her',
#   'cast': ['Jimmy Bennett', 'Hunter King', 'Lexi Ainsworth', 'Luke Jaden'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'A Fuller Life',
#   'cast': ['Samuel Fuller', 'Jennifer Beals', 'Robert Carradine', 'Joe Dante'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'A Fare to Remember',
#   'cast': ['Malcolm-Jamal Warner',
#    'Challen Cates',
#    'Max Alexander',
#    'Peter Birkenhead'],
#   'tomatoes': {'viewer': {'rating': 4.6}},
#   'num_favs': 0},
#  {'title': 'Zombie Night',
#   'cast': ['Anthony Michael Hall',
#    'Daryl Hannah',
#    'Alan Ruck',
#    'Rachel G. Fox'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Without Warning',
#   'cast': ['Jack Palance',
#    'Martin Landau',
#    'Tarah Nutter',
#    'Christopher S. Nelson'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Who Killed Chea Vichea?',
#   'cast': ['Samnang Born', 'Vichea Chea', 'Eric Milano', 'Rainsy Sam'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Whiplash',
#   'cast': ['Miles Teller', 'J.K. Simmons', 'Paul Reiser', 'Melissa Benoist'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Wax, or the Discovery of Television Among the Bees',
#   'cast': ['Father Bessarion',
#    'David Blair',
#    'William S. Burroughs',
#    'Florence Ormezzano'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Wait Until Spring, Bandini',
#   'cast': ['Joe Mantegna', 'Ornella Muti', 'Faye Dunaway', 'Michael Bacall'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Vincent: A Life in Color',
#   'cast': ['Vincent Falk'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Vanessa: Her Love Story',
#   'cast': ['Robert Montgomery', 'Helen Hayes', 'May Robson', 'Otto Kruger'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Untitled Spider-Man Reboot',
#   'cast': ['Tom Holland', 'Marisa Tomei'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Toward the Unknown',
#   'cast': ['William Holden',
#    'Lloyd Nolan',
#    'Virginia Leith',
#    'Charles McGraw'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': "Tom and Jerry's Giant Adventure",
#   'cast': ['Jacob Bertrand',
#    'Thomas F. Wilson',
#    'Grey Griffin',
#    'Garrison Keillor'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'To Cross the Rubicon',
#   'cast': ['Patricia Royce',
#    'Lorraine Devon Wilke',
#    'JD Souther',
#    'Wade Madsen'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Titanic: The Final Word with James Cameron',
#   'cast': ['James Cameron',
#    'Ken Marschall',
#    'Paul-Henri Nargeolet',
#    'Bill Sauder'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'Tin Man',
#   'cast': ['Zooey Deschanel',
#    'Alan Cumming',
#    'Neal McDonough',
#    'Kathleen Robertson'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'The Wild Party',
#   'cast': ['Anthony Quinn', 'Carol Ohmart', 'Arthur Franz', 'Jay Robinson'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'The Target Shoots First',
#   'cast': ['Christopher Wilcha',
#    'Marie Capozzi',
#    'Rick Hunt',
#    'John S. Wilcha'],
#   'tomatoes': {'viewer': {'rating': 4.5}},
#   'num_favs': 0},
#  {'title': 'The Peanuts Movie',
#   'cast': ['Francesca Capaldi',
# ...
#   'num_favs': 0},
#  {'title': 'The Wrecking Crew',
#   'cast': ['Lou Adler', 'Herb Alpert', 'The Association', 'H.B. Barnum'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Work of Director Jonathan Glazer',
#   'cast': ['Milo Addica',
#    'Jean-Claude Carri�re',
#    'Nick Cave',
#    'Olegar Fedoro'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Wizards Return: Alex vs. Alex',
#   'cast': ['Selena Gomez', 'Jake T. Austin', 'Jennifer Stone', 'Gregg Sulkin'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Wind',
#   'cast': ['Lillian Gish', 'Lars Hanson', 'Montagu Love', 'Dorothy Cumming'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Wild Bunch',
#   'cast': ['William Holden',
#    'Ernest Borgnine',
#    'Robert Ryan',
#    "Edmond O'Brien"],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The White Stripes Under Great White Northern Lights',
#   'cast': ['Alex Debogorski', 'Maria Durham', 'Jack White', 'Meg White'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Untold Story of Emmett Louis Till',
#   'cast': ['Mamie Till',
#    'Wheeler Parker',
#    'Simeon Wright',
#    'Ruthie Mae Crawford'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Unknown',
#   'cast': ['Lon Chaney', 'Norman Kerry', 'Joan Crawford', 'Nick De Ruiz'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Tillman Story',
#   'cast': ['Josh Brolin', 'Pat Tillman', 'Mary Tillman', 'Russell Baer'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Thin Blue Line',
#   'cast': ['Randall Adams', 'David Harris', 'Gus Rose', 'Jackie Johnson'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': "The Strange History of Don't Ask, Don't Tell",
#   'cast': ['Carl Levin', 'Robert Gates', 'Mike Mullen', 'John McCain'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Strange Door',
#   'cast': ['Charles Laughton',
#    'Boris Karloff',
#    'Sally Forrest',
#    'Richard Wyler'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Stoning of Soraya M.',
#   'cast': ['Shohreh Aghdashloo',
#    'Mozhan Marn�',
#    'Jim Caviezel',
#    'Navid Negahban'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Sting',
#   'cast': ['Paul Newman', 'Robert Redford', 'Robert Shaw', 'Charles Durning'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Social Network',
#   'cast': ['Jesse Eisenberg',
#    'Rooney Mara',
#    'Bryan Barter',
#    'Dustin Fitzsimons'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Silence of the Lambs',
#   'cast': ['Jodie Foster',
#    'Lawrence A. Bonney',
#    'Kasi Lemmons',
#    'Lawrence T. Wrentz'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Shop Around the Corner',
#   'cast': ['Margaret Sullavan',
#    'James Stewart',
#    'Frank Morgan',
#    'Joseph Schildkraut'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Shamrock Handicap',
#   'cast': ['Janet Gaynor',
#    'Leslie Fenton',
#    'Willard Louis',
#    'J. Farrell MacDonald'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Secrets of Jonathan Sperry',
#   'cast': ['Gavin MacLeod',
#    'Jansen Panettiere',
#    'Robert Guillaume',
#    'Frankie Ryan Manriquez'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Secret of Santa Vittoria',
#   'cast': ['Anthony Quinn', 'Anna Magnani', 'Virna Lisi', 'Hardy Kr�ger'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Revolutionary',
#   'cast': ['Jon Voight',
#    'Seymour Cassel',
#    'Robert Duvall',
#    'Collin Wilcox Paxton'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Raid: Redemption',
#   'cast': ['Iko Uwais', 'Joe Taslim', 'Donny Alamsyah', 'Yayan Ruhian'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Quiet Man',
#   'cast': ['John Wayne', "Maureen O'Hara", 'Barry Fitzgerald', 'Ward Bond'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Prodigy',
#   'cast': ['Holt Boggs', 'Glen Vorhis', 'Matt Beckham', 'Diana Lee Inosanto'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Point',
#   'cast': ['Ringo Starr', 'Paul Frees', 'Lennie Weinrib', 'Bill Martin'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Play House',
#   'cast': ['Buster Keaton'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Plague Dogs',
#   'cast': ['John Hurt',
#    'Christopher Benjamin',
#    'James Bolam',
#    'Nigel Hawthorne'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Philadelphia Story',
#   'cast': ['Cary Grant', 'Katharine Hepburn', 'James Stewart', 'Ruth Hussey'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Perfect Student',
#   'cast': ['Natasha Henstridge', 'Josie Davis', 'Brea Grant', 'Jay Pickett'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Perfect Human Diet',
#   'cast': ['C.J. Hunt',
#    'Leslie Aiello',
#    'Susan Loraine Anderson',
#    'Loren Cordain'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon Papers',
#   'cast': ['Peter Arnett', 'Ben Bagdikian', 'Ann Beeson', 'John Dean'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Model Solution',
#   'cast': ['Jason Schnuit', 'Holly Hollywood', 'Sebastien Guy', 'Kim Yates'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Mad Doctor',
#   'cast': ['Pinto Colvig', 'Walt Disney'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'cast': ['Bruce Allpress', 'Sean Astin', 'John Bach', 'Sala Baker'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'cast': ['Alan Howard', 'Noel Appleby', 'Sean Astin', 'Sala Baker'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Lorax',
#   'cast': ['Eddie Albert', 'Bob Holt', 'Athena Lorde', 'Harlen Carraher'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Lion in Winter',
#   'cast': ["Peter O'Toole",
#    'Katharine Hepburn',
#    'Anthony Hopkins',
#    'John Castle'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Legend of Sleepy Hollow',
#   'cast': ['Bing Crosby'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Last Picture Show',
#   'cast': ['Timothy Bottoms',
#    'Jeff Bridges',
#    'Cybill Shepherd',
#    'Ben Johnson'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Lady Eve',
#   'cast': ['Barbara Stanwyck',
#    'Henry Fonda',
#    'Charles Coburn',
#    'Eugene Pallette'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Killing',
#   'cast': ['Sterling Hayden',
#    'Coleen Gray',
#    'Vince Edwards',
#    'Jay C. Flippen'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Journey',
#   'cast': ['Roshan Seth', 'Saeed Jaffrey', 'Antony Zaki', 'Carrie Preston'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Jacksons: An American Dream',
#   'cast': ['Lawrence Hilton-Jacobs',
#    'Angela Bassett',
#    'Holly Robinson Peete',
#    'Margaret Avery'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Invisible War',
#   'cast': ['Amy Ziering', 'Kirby Dick', 'Kori Cioca', 'Jessica Hinves'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Intern',
#   'cast': ['Anne Hathaway', 'Robert De Niro', 'Nat Wolff', 'Rene Russo'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Immigrant',
#   'cast': ['Charles Chaplin',
#    'Edna Purviance',
#    'Eric Campbell',
#    'Albert Austin'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Hunger Games',
#   'cast': ['Stanley Tucci',
#    'Wes Bentley',
#    'Jennifer Lawrence',
#    'Willow Shields'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The House of the Seven Gables',
#   'cast': ['George Sanders',
#    'Margaret Lindsay',
#    'Vincent Price',
#    'Dick Foran'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The House I Live In',
#   'cast': ['Eugene Jarecki', 'Nannie Jeter', 'Betty Chism', 'Dennis Whidbee'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': "The Hornet's Nest",
#   'cast': ['Carlos Boettcher', 'Mike Boettcher', 'Kalen M. Waite'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Hobbit: The Desolation of Smaug',
#   'cast': ['Ian McKellen', 'Martin Freeman', 'Richard Armitage', 'Ken Stott'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Hobbit: An Unexpected Journey',
#   'cast': ['Ian McKellen', 'Martin Freeman', 'Richard Armitage', 'Ken Stott'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The History of Future Folk',
#   'cast': ["Nils d'Aulaire",
#    'Jay Klaitz',
#    'Julie Ann Emery',
#    'April L. Hernandez'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Hiding Place',
#   'cast': ['Julie Harris',
#    'Jeannette Clift',
#    "Arthur O'Connell",
#    'Robert Rietty'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Hammer',
#   'cast': ['Adam Carolla',
#    'Oswaldo Castillo',
#    'Harold House Moore',
#    'Christopher Darga'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Halloween Tree',
#   'cast': ['Ray Bradbury', 'Leonard Nimoy', 'Annie Barker', 'Alex Greenwald'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Great Man Votes',
#   'cast': ['John Barrymore',
#    'Peter Holden',
#    'Virginia Weidler',
#    'Katharine Alexander'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Grand Budapest Hotel',
#   'cast': ['F. Murray Abraham',
#    'Adrien Brody',
#    'Mathieu Amalric',
#    'Ralph Fiennes'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Gold Rush',
#   'cast': ['Charles Chaplin', 'Mack Swain', 'Tom Murray', 'Henry Bergman'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Girl with the Dragon Tattoo',
#   'cast': ['Daniel Craig',
#    'Rooney Mara',
#    'Christopher Plummer',
#    'Stellan Skarsg�rd'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Flight of Dragons',
#   'cast': ['James Gregory',
#    'Harry Morgan',
#    'James Earl Jones',
#    'Victor Buono'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Five Pennies',
#   'cast': ['Danny Kaye',
#    'Barbara Bel Geddes',
#    'Louis Armstrong',
#    'Harry Guardino'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Final Girls',
#   'cast': ['Taissa Farmiga',
#    'Nina Dobrev',
#    'Malin Akerman',
#    'Alexander Ludwig'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Fighter',
#   'cast': ['Mark Wahlberg', 'Christian Bale', 'Amy Adams', 'Melissa Leo'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Feminine Touch',
#   'cast': ['Rosalind Russell', 'Don Ameche', 'Kay Francis', 'Van Heflin'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Farm: Angola, USA',
#   'cast': ['Bernard Addison',
#    'Burl Cain',
#    'George Crawford',
#    'Wilbert Rideau'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Endless Summer',
#   'cast': ['Michael Hynson',
#    'Robert August',
#    "Lord 'Tally Ho' Blears",
#    'Bruce Brown'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Elephant in the Living Room',
#   'cast': ['Tim Harrison', 'Terry Brumfield', 'Russ Clear', 'Casey Craig'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Dogwalker',
#   'cast': ['Diane Gaidry', 'Pamela Gordon', 'Lyn Vaus', 'Lisa Jane Persky'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Devil Came on Horseback',
#   'cast': ['Nicholas Kristof', 'Brian Steidle'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Departed',
#   'cast': ['Leonardo DiCaprio',
#    'Matt Damon',
#    'Jack Nicholson',
#    'Mark Wahlberg'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Deer Hunter',
#   'cast': ['Robert De Niro',
#    'John Cazale',
#    'John Savage',
#    'Christopher Walken'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Decline of Western Civilization',
#   'cast': ['Alice Bag Band', 'Alice Bag', 'Claude Bessey', 'Black Flag'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Danish Girl',
#   'cast': ['Alicia Vikander',
#    'Eddie Redmayne',
#    'Amber Heard',
#    'Matthias Schoenaerts'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Dangerous Lives of Altar Boys',
#   'cast': ['Emile Hirsch',
#    'Kieran Culkin',
#    "Vincent D'Onofrio",
#    'Jena Malone'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Conversation',
#   'cast': ['Gene Hackman',
#    'John Cazale',
#    'Allen Garfield',
#    'Frederic Forrest'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Confession',
#   'cast': ['Ben Kingsley', 'Amy Irving', 'Ryan Marsini', 'Alec Baldwin'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Complete Truth About De-Evolution',
#   'cast': ['Bob Casale',
#    'Gerald V. Casale',
#    'David Kendrick',
#    'Mark Mothersbaugh'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Christmas Shoes',
#   'cast': ['Rob Lowe',
#    'Kimberly Williams-Paisley',
#    'Max Morrow',
#    'Maria del Mar'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Central Park Five',
#   'cast': ['Antron McCray',
#    'Kevin Richardson',
#    'Yusef Salaam',
#    'Raymond Santana'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Bourne Ultimatum',
#   'cast': ['Matt Damon', 'Julia Stiles', 'David Strathairn', 'Scott Glenn'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Big Sleep',
#   'cast': ['Humphrey Bogart',
#    'Lauren Bacall',
#    'John Ridgely',
#    'Martha Vickers'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Big Blue',
#   'cast': ['Rosanna Arquette', 'Jean-Marc Barr', 'Jean Reno', 'Paul Shenar'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Bed You Sleep In',
#   'cast': ['Tom Blair',
#    'Marshall Gaddis',
#    'Ellen McLaughlin',
#    'Kate Sannella'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Beans of Egypt, Maine',
#   'cast': ['Martha Plimpton', 'Kelly Lynch', 'Rutger Hauer', 'Patrick McGaw'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Anatomy of Hate',
#   'cast': ['Justin Barrett', 'Kerry Noble', 'Terrence Deacon', 'Fred Phelps'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The Activist',
#   'cast': ['Chadwick Brown',
#    'Tonantzin Carmelo',
#    'Michael Spears',
#    'Ron Rogg�'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': 'The 27 Club',
#   'cast': ['Joe Anderson', 'David P. Emrich', 'Eve Hewson', 'Alexie Gilmore'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  {'title': "The 'High Sign'",
#   'cast': ['Buster Keaton'],
#   'tomatoes': {'viewer': {'rating': 4.1}},
#   'num_favs': 0},
#  ...]

# %%
predicate = {

}

# %%
projection = {

}

# %%
sorting = {

}

# %%
skipping = {

}

# %%
limiting = {

}

# %%
pipeline = [
    predicate,
    projection,
    sorting,
    skipping,
    limiting
]

display(list(movies.aggregate(pipeline)))
